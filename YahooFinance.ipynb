# %% [markdown]
# # Part 1

# %% [markdown]
# 1.   Create a **colored candlestick chart with daily market capitalization and simple moving average** lines for the company **Microsft** using the downloader of Yahoo finance, using **MatplotLib finance package**.
# 2.   Using the same information previously obtain (**Microsoft**), plot a **scatterplot** of the **close price** **with and without the weekends**, using **plotly**. Add also a **rangeslider**.
# 3.   Using plotly and Yahoo finance, create a new figure in paralalel with **3 stocks** (Apple, Microsoft, and google). **Show the head and tails **of the information and plot simultaneously, **without weekends** and including the **reangeslider**.
# 4. **Create the Black-Schles-Merton** equation to cover Call, Put Option. Take into account that to program in python the cumulative normal we will use the following command si.norm.cdf(d1), from the package statistical package of Scypy. To import please run this command:
# `import scipy.stats as si`
#
# You can check your results in the following website:
# https://www.math.drexel.edu/~pg/fin/VanillaCalculator.html

# %%
import numpy as np #this code will allow you to work with numpy algorithms.
import scipy as sp #this will import interesting scientific functions
import pylab as plt # this code will allow you to work with graph library

# !pip install mplfinance -q # -q for quiet
import mplfinance as mpf
import pandas as pd

from datetime import datetime
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 1.3 MB/s eta 0:00:00

# %%
# !pip install yfinance --quiet
import yfinance as yf

appl=yf.Ticker('APPL')
fb=yf.Ticker('META')
goog=yf.Ticker('GOOG')
amzn=yf.Ticker('AMZN')
sq=yf.Ticker('SQ')
tsla=yf.Ticker('TSLA')
gspc=yf.Ticker('GSPC')
ms=yf.Ticker('MSFT')

# %%
Microsoft = yf.download('MSFT',
                       start = '2023-01-01',
                       #end = '2023-08-15',
                       progress = False
                       )
Microsoft.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  243.080002  245.750000  237.399994  239.580002  237.956329
# 2023-01-04  232.279999  232.869995  225.960007  229.100006  227.547363
# 2023-01-05  227.199997  227.550003  221.759995  222.309998  220.803360
# 2023-01-06  223.000000  225.759995  219.350006  224.929993  223.405609
# 2023-01-09  226.449997  231.240005  226.410004  227.119995  225.580765
#
#               Volume
# Date
# 2023-01-03  25740000
# 2023-01-04  50623400
# 2023-01-05  39585600
# 2023-01-06  43613600
# 2023-01-09  27369800

# %% [markdown]
# 1.
# Colored candlestick chart with daily market price and simple moving average lines for the company Microsft using the downloader of Yahoo finance, using MatplotLib finance package.

# %%
mpf.plot(Microsoft,
        type = 'candle',
        style =  'charles',
        title = 'Microsoft',
        ylabel = 'Prices',
        figratio=(12,8),
        volume = True,
        show_nontrading = True,
        ylabel_lower='Volume of \n traded shares',
        mav = (8, 20, 50))

# %% [markdown]
# 2a. Scatter plot of Microsoft close price with weekend using plotly with rangeslider

# %%
import plotly.graph_objects as go
import plotly.express as px

fig = px.scatter(x=Microsoft.index, y=Microsoft["Close"],
                 title="show Gaps with rangebreaks")
fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 2b. Scatter plot of Microsoft close price without weekend using plotly with rangeslider

# %%
fig = px.scatter(x=Microsoft.index, y=Microsoft["Close"],
                 title="show Gaps with rangebreaks")

fig.update_xaxes(
    rangebreaks=[
        dict(bounds=["sat", "mon"]), #hide weekends
        dict(values=["2015-12-25", "2016-01-01"])  # hide Christmas and New Year's
    ]
)

fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 3.Using plotly and Yahoo finance, create a new figure in paralalel with 3 stocks (Apple, Microsoft, and google). Show the head and tails *of the information and plot simultaneously, *without weekends and including the reangeslider.

# %%
Meta = yf.download('META',
                       start = '2023-01-01',
                       #end = '2023-08-15',
                       progress = False
                       )

Google = yf.download('GOOG',
                       start = '2023-01-01',
                       #end = '2023-08-15',
                       progress = False
                       )
Meta.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-01-03  122.820000  126.370003  122.279999  124.739998  124.739998
# 2023-01-04  127.379997  129.050003  125.849998  127.370003  127.370003
# 2023-01-05  126.129997  128.520004  124.540001  126.940002  126.940002
# 2023-01-06  128.970001  130.330002  126.040001  130.020004  130.020004
# 2023-01-09  131.160004  132.949997  129.279999  129.470001  129.470001
#
#               Volume
# Date
# 2023-01-03  35528500
# 2023-01-04  32397100
# 2023-01-05  25447100
# 2023-01-06  27584500
# 2023-01-09  26649100

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import pandas as pd

fig = make_subplots(rows=1, cols=3,
                    subplot_titles=('Microsoft', 'Meta', 'Google'))

trace1 = go.Scatter(x=Microsoft.index, y=Microsoft['High'], mode='lines',name='Microsoft')
fig.add_trace(trace1, row=1, col=1)

trace1 = go.Scatter(x=Meta.index, y=Meta['High'], mode='lines', name='Meta')
fig.add_trace(trace1, row=1, col=2)

trace1 = go.Scatter(x=Google.index, y=Google['High'], mode='lines', name='Google')
fig.add_trace(trace1, row=1, col=3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 4.**Create the Black-Scholes-Merton** equation to cover Call, Put Option. Take into account that to program in python the cumulative normal we will use the following command si.norm.cdf(d1), from the package statistical package of Scypy. To import please run this command:
# `import scipy.stats as si`

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import numpy as np
import scipy.stats as si
import sympy as sy
#import sympy.statistics as systats

# %%
def European_Call_Option (S,K,r,q,sigma,t):
    #S: spot price
    #K: strike price
    #T: time to maturity
    #r: interest rate
    #sigma: volatility of underlying asset
    #q: dividend yield (usually 0)

    d1 = 1/(sigma*np.sqrt(t))*(np.log(S/K)+(r-q+(sigma**2)/2)*t)
    d2 = d1 - sigma*np.sqrt(t)
    call = si.norm.cdf(d1)*S*np.exp(-q*t) - si.norm.cdf(d2)*K*np.exp(-r*t)

    return call

# %%
European_Call_Option (50,100,0.05,0,0.25,1)
# Out:
# 0.027352509369436673

# %%
def European_Put_Option (S,K,r,q,sigma,t):
    #S: spot price
    #K: strike price
    #T: time to maturity
    #r: interest rate
    #sigma: volatility of underlying asset
    #q: dividend yield (usually 0)

    d1 = 1/(sigma*np.sqrt(t))*(np.log(S/K)+(r-q+(sigma**2)/2)*t)
    d2 = d1 - sigma*np.sqrt(t)
    put = -si.norm.cdf(-d1)*S*np.exp(-q*t) - si.norm.cdf(-d2)*K*np.exp(-r*t)

    return put

# %%
European_Put_Option (50, 100, 0.05, 0, 0.20, 1)
# Out:
# -45.125341867624705

# %% [markdown]
# # Part 2

# %% [markdown]
# The following results were produced in this notebook:
#
# 1. Download from yahoo the following tickers = ['AAPL', 'META', 'GOOG', 'AMZN',  'SQ', 'TSLA', '^GSPC'], from 2020/01/01.
# 2. Plot the "Adj Close" for all equties in the very same plot using Plotly.
# 3. Calculte the precentage of value increase for all the companies, or Standarize Price from 2020/01/01.
# 4. Plot the Standarize plot in a Plotly for all tickers
# 5. Calculate current increase since 2020/01/01, and show it in the command window.

# %%
import numpy as np
import scipy as sp

# %% [markdown]
# 1. Download from yahoo the following tickers = ['META', 'GOOG', 'AMZN', 'SQ', 'TSLA', '^GSPC'], from 2020/01/01.

# %%
# !pip install yfinance --quiet
import yfinance as yf

Meta = yf.download('META',
                       start = '2020-01-01',
                       #end = '2023-08-15',
                       progress = False
                       )

Google = yf.download('GOOG',
                       start = '2020-01-01',
                       #end = '2023-08-15',
                       progress = False
                       )

Amazon = yf.download('AMZN',
                       start = '2020-01-01',
                       #end = '2023-08-15',
                       progress = False
                       )

Block = yf.download('SQ',
                       start = '2020-01-01',
                       #end = '2023-08-15',
                       progress = False
                       )

Tesla = yf.download('TSLA',
                       start = '2020-01-01',
                       #end = '2023-08-15',
                       progress = False
                       )

SP500 = yf.download('^GSPC',
                       start = '2020-01-01',
                       #end = '2023-08-15',
                       progress = False
                       )

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import pandas as pd

# %%
Meta.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-01-02  206.750000  209.789993  206.270004  209.779999  209.779999
# 2020-01-03  207.210007  210.399994  206.949997  208.669998  208.669998
# 2020-01-06  206.699997  212.779999  206.520004  212.600006  212.600006
# 2020-01-07  212.820007  214.580002  211.750000  213.059998  213.059998
# 2020-01-08  213.000000  216.240005  212.610001  215.220001  215.220001
#
#               Volume
# Date
# 2020-01-02  12077100
# 2020-01-03  11188400
# 2020-01-06  17058900
# 2020-01-07  14912400
# 2020-01-08  13475000

# %% [markdown]
# 2. Plot the "Adj Close" for all equties in the very same plot using Plotly.

# %%
trace1 = go.Scatter(x= Meta.index, y=Meta['Adj Close'], mode='lines', name='Meta')
trace2 = go.Scatter(x= Google.index, y=Google['Adj Close'], mode='lines', name='Google')
trace3 = go.Scatter(x= Amazon.index, y=Amazon['Adj Close'], mode='lines', name='Amazon')
trace4 = go.Scatter(x= Block.index, y=Block['Adj Close'], mode='lines', name='Block')
trace5 = go.Scatter(x= Tesla.index, y=Tesla['Adj Close'], mode='lines', name='Tesla')
trace6 = go.Scatter(x= SP500.index, y=SP500['Adj Close'], mode='lines', name='S&P500 Index')


# Create a layout
layout = go.Layout(
    title='S&P 500 Index and Adjusted Close Price for 5 Stocks since 2020-01-01',
    xaxis=dict(title='Time'),
    yaxis=dict(title='Price')
)

# Create a figure and add traces
fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6], layout=layout)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 3. Calculte the precentage of value increase for all the companies, or Standarize Price from 2020/01/01.
# 4. Plot the Standarize plot in a Plotly for all tickers

# %%
Meta['Standardized Closing Price']=(Meta['Close'] - Meta['Close'].iloc[0]) / Meta['Close'].iloc[0] * 100
Google['Standardized Closing Price']=(Google['Close'] - Google['Close'].iloc[0]) / Google['Close'].iloc[0] * 100
Amazon['Standardized Closing Price']=(Amazon['Close'] - Amazon['Close'].iloc[0]) / Amazon['Close'].iloc[0] * 100
Block['Standardized Closing Price']=(Block['Close'] - Block['Close'].iloc[0]) / Block['Close'].iloc[0] * 100
Tesla['Standardized Closing Price']=(Tesla['Close'] - Tesla['Close'].iloc[0]) / Tesla['Close'].iloc[0] * 100
SP500['Standardized Closing Price']=(SP500['Close'] - SP500['Close'].iloc[0]) / SP500['Close'].iloc[0] * 100

# %%
trace1 = go.Scatter(x= Meta.index, y=Meta['Standardized Closing Price'], mode='lines', name='Meta')
trace2 = go.Scatter(x= Google.index, y=Google['Standardized Closing Price'], mode='lines', name='Google')
trace3 = go.Scatter(x= Amazon.index, y=Amazon['Standardized Closing Price'], mode='lines', name='Amazon')
trace4 = go.Scatter(x= Block.index, y=Block['Standardized Closing Price'], mode='lines', name='Block')
trace5 = go.Scatter(x= Tesla.index, y=Tesla['Standardized Closing Price'], mode='lines', name='Tesla')
trace6 = go.Scatter(x= SP500.index, y=SP500['Standardized Closing Price'], mode='lines', name='S&P500 Index')


# Create a layout
layout = go.Layout(
    title='S&P 500 Index and Standardized Closing Price for 5 Stocks since 2020-01-01',
    xaxis=dict(title='Time'),
    yaxis=dict(title='Price')
)

# Create a figure and add traces
fig = go.Figure(data=[trace1, trace2, trace3, trace4, trace5, trace6], layout=layout)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 5. Calculate current increase since 2020/01/01, and show it in the command window.

# %%
#Meta, Google, Amazon, Block, Tesla, S&P 500
Meta_last = Meta['Standardized Closing Price'].iloc[-1]
Google_last = Google['Standardized Closing Price'].iloc[-1]
Amazon_last = Amazon['Standardized Closing Price'].iloc[-1]
Block_last = Block['Standardized Closing Price'].iloc[-1]
Tesla_last = Tesla['Standardized Closing Price'].iloc[-1]
SP500_last = SP500['Standardized Closing Price'].iloc[-1]

print('Meta current price % increase compared to 2020-01-01: ', Meta_last)
print('Google current price % increase compared to 2020-01-01: ', Google_last)
print('Amazon current price % increase compared to 2020-01-01: ', Amazon_last)
print('Block current price % increase compared to 2020-01-01: ', Block_last)
print('Tesla current price % increase compared to 2020-01-01: ', Tesla_last)
print('S&P 500 current index % increase compared to 2020-01-01: ', SP500_last)
# Out:
# Meta current price % increase compared to 2020-01-01:  42.568399424445865
# Google current price % increase compared to 2020-01-01:  91.97437484907148
# Amazon current price % increase compared to 2020-01-01:  36.058291162859945
# Block current price % increase compared to 2020-01-01:  -29.954570261785165
# Tesla current price % increase compared to 2020-01-01:  753.7163741198776
# S&P 500 current index % increase compared to 2020-01-01:  32.60462971275661
